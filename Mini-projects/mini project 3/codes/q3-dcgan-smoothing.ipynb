# %%
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from keras.datasets import cifar10
from keras.models import Sequential, Model
from keras.layers import Input, Dense, LeakyReLU, BatchNormalization, ReLU
from keras.layers import Conv2D, Conv2DTranspose, Reshape, Flatten
from keras.optimizers import Adam
from keras import initializers
from keras.utils import plot_model, np_utils
from keras import backend as K

# %%
# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# %%
fig = plt.figure(figsize=(8,3))
for i in range(0, 10):
    plt.subplot(2, 5, 1 + i, xticks=[], yticks=[])
    plt.imshow(X_train[i])
    
plt.tight_layout()

# %%
num_classes = len(np.unique(y_train))
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']

fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = plt.subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(y_train[:]==i)[0]
    features_idx = X_train[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    img = features_idx[img_num,::]
    ax.set_title(class_names[i])
    plt.imshow(img)
    
plt.tight_layout()

# %%
print('X_train shape:', X_train.shape)
print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'test samples')
# Out:
# X_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
if K.image_data_format() == 'channels_first':
    X_train = X_train.reshape(X_train.shape[0], 3, 32, 32)
    X_test = X_test.reshape(X_test.shape[0], 3, 32, 32)
    input_shape = (3, 32, 32)
else:
    X_train = X_train.reshape(X_train.shape[0], 32, 32, 3)
    X_test = X_test.reshape(X_test.shape[0], 32, 32, 3)
    input_shape = (32, 32, 3)
    
# convert class vectors to binary class matrices
Y_train = np_utils.to_categorical(y_train, num_classes)
Y_test = np_utils.to_categorical(y_test, num_classes)

# the generator is using tanh activation, for which we need to preprocess 
# the image data into the range between -1 and 1.

X_train = np.float32(X_train)
X_train = (X_train / 255 - 0.5) * 2
X_train = np.clip(X_train, -1, 1)

X_test = np.float32(X_test)
X_test = (X_train / 255 - 0.5) * 2
X_test = np.clip(X_test, -1, 1)

print('X_train reshape:', X_train.shape)
print('X_test reshape:', X_test.shape)
# Out:
# X_train reshape: (50000, 32, 32, 3)
# X_test reshape: (50000, 32, 32, 3)

# %% [markdown]
# #Define Models

# %%
# latent space dimension
latent_dim = 100

init = initializers.RandomNormal(stddev=0.02)

# Generator network
generator = Sequential()

# FC: 2x2x512
generator.add(Dense(2*2*512, input_shape=(latent_dim,), kernel_initializer=init))
generator.add(Reshape((2, 2, 512)))
generator.add(BatchNormalization())
generator.add(LeakyReLU(0.2))

# # Conv 1: 4x4x256
generator.add(Conv2DTranspose(256, kernel_size=5, strides=2, padding='same'))
generator.add(BatchNormalization())
generator.add(LeakyReLU(0.2))

# Conv 2: 8x8x128
generator.add(Conv2DTranspose(128, kernel_size=5, strides=2, padding='same'))
generator.add(BatchNormalization())
generator.add(LeakyReLU(0.2))

# Conv 3: 16x16x64
generator.add(Conv2DTranspose(64, kernel_size=5, strides=2, padding='same'))
generator.add(BatchNormalization())
generator.add(LeakyReLU(0.2))

# Conv 4: 32x32x3
generator.add(Conv2DTranspose(3, kernel_size=5, strides=2, padding='same',
                              activation='tanh'))
generator.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 2048)              206848
# _________________________________________________________________
# reshape_5 (Reshape)          (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_transpose_17 (Conv2DT (None, 4, 4, 256)         3277056
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_transpose_18 (Conv2DT (None, 8, 8, 128)         819328
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_transpose_19 (Conv2DT (None, 16, 16, 64)        204864
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_transpose_20 (Conv2DT (None, 32, 32, 3)         4803
# =================================================================
# Total params: 4,516,739
# Trainable params: 4,514,819
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
# imagem shape 32x32x3
img_shape = X_train[0].shape

# Discriminator network
discriminator = Sequential()

# Conv 1: 16x16x64
discriminator.add(Conv2D(64, kernel_size=5, strides=2, padding='same',
                         input_shape=(img_shape), kernel_initializer=init))
discriminator.add(LeakyReLU(0.2))

# Conv 2:
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding='same'))
discriminator.add(BatchNormalization())
discriminator.add(LeakyReLU(0.2))

# Conv 3: 
discriminator.add(Conv2D(256, kernel_size=5, strides=2, padding='same'))
discriminator.add(BatchNormalization())
discriminator.add(LeakyReLU(0.2))

# Conv 3: 
discriminator.add(Conv2D(512, kernel_size=5, strides=2, padding='same'))
discriminator.add(BatchNormalization())
discriminator.add(LeakyReLU(0.2))

# FC
discriminator.add(Flatten())

# Output
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 16, 16, 64)        4864
# _________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)   (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 128)         204928
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 8, 8, 128)         512
# _________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)   (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 256)         819456
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)   (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 2, 2, 512)         3277312
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 2, 2, 512)         2048
# _________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)   (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 2049
# =================================================================
# Total params: 4,312,193
# Trainable params: 4,310,401
# Non-trainable params: 1,792
# _________________________________________________________________

# %%
# Optimizer

discriminator.compile(Adam(lr=0.0003, beta_1=0.5), loss='binary_crossentropy',
                      metrics=['binary_accuracy', 'acc'])

# %%
# d_g = discriminador(generador(z))
discriminator.trainable = False

z = Input(shape=(latent_dim,))
img = generator(z)
decision = discriminator(img)
d_g = Model(inputs=z, outputs=decision)

d_g.compile(Adam(lr=0.0004, beta_1=0.5), loss='binary_crossentropy',
            metrics=['binary_accuracy', 'acc'])

# %%
# prints a summary representation of your model
d_g.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 100)               0
# _________________________________________________________________
# sequential_9 (Sequential)    (None, 32, 32, 3)         4516739
# _________________________________________________________________
# sequential_10 (Sequential)   (None, 1)                 4312193
# =================================================================
# Total params: 8,828,932
# Trainable params: 4,514,819
# Non-trainable params: 4,314,113
# _________________________________________________________________

# %%
epochs = 50
batch_size = 64
smooth = 0.1

real = np.ones(shape=(batch_size, 1))
fake = np.zeros(shape=(batch_size, 1))

d_loss = []
g_loss = []
d_loss_for_plot = []
g_loss_for_plot = []

for e in range(epochs + 1):
    for i in range(len(X_train) // batch_size):
        
        # Train Discriminator weights
        discriminator.trainable = True
        
        # Real samples
        X_batch = X_train[i*batch_size:(i+1)*batch_size]
        d_loss_real = discriminator.train_on_batch(x=X_batch,
                                                   y=real * (1 - smooth))
        
        # Fake Samples
#         z = np.random.normal(loc=0, scale=1, size=(batch_size, latent_dim))
        z = np.random.uniform(low=-1, high=1, size=[batch_size, latent_dim])
        X_fake = generator.predict_on_batch(z)
        d_loss_fake = discriminator.train_on_batch(x=X_fake, y=fake)
        
         
        # Discriminator loss
        d_loss_batch = [x+y for x,y in zip(d_loss_real, d_loss_fake)]
        d_loss_batch = [0.5*x for x in d_loss_batch]

        
        # Train Generator weights
        discriminator.trainable = False
        g_loss_batch = d_g.train_on_batch(x=z, y=real)

        print(
            'epoch = %d/%d, batch = %d/%d, d_loss=%.3f, g_loss=%.3f' % (e + 1, epochs, i, len(X_train) // batch_size, d_loss_batch[0], g_loss_batch[0]),
            100*' ',
            end='\r'
        )
    # print('epoch:{}, batch:{}'.format(e, i))
    d_loss.append(d_loss_batch[0])
    d_loss_for_plot.append(d_loss_batch)
    g_loss.append(g_loss_batch[0])
    g_loss_for_plot.append(g_loss_batch)
    print('epoch = %d/%d, d_loss=%.3f, g_loss=%.3f' % (e + 1, epochs, d_loss[-1], g_loss[-1]), 100*' ')

    if e % 5 == 0:
        samples = 100
        x_fake = generator.predict(np.random.normal(loc=0, scale=1, size=(samples, latent_dim)))
        plt.figure(figsize=[10, 10])
        for k in range(samples):
            plt.subplot(10, 10, k + 1, xticks=[], yticks=[])
            plt.imshow(((x_fake[k] + 1)* 127).astype(np.uint8))

        plt.tight_layout()
        plt.show()
# Out:
# epoch = 1/50, d_loss=1.432, g_loss=9.994
# epoch = 2/50, d_loss=0.172, g_loss=0.080
# epoch = 3/50, d_loss=0.214, g_loss=3.581
# epoch = 4/50, d_loss=0.185, g_loss=0.032
# epoch = 5/50, d_loss=0.200, g_loss=5.241
# epoch = 6/50, d_loss=0.256, g_loss=2.195
# epoch = 7/50, d_loss=0.205, g_loss=3.559
# epoch = 8/50, d_loss=0.221, g_loss=3.470
# epoch = 9/50, d_loss=0.217, g_loss=3.753
# epoch = 10/50, d_loss=0.272, g_loss=4.156
# epoch = 11/50, d_loss=0.186, g_loss=1.645
# epoch = 12/50, d_loss=0.222, g_loss=5.086
# epoch = 13/50, d_loss=0.191, g_loss=4.448
# epoch = 14/50, d_loss=0.207, g_loss=5.022
# epoch = 15/50, d_loss=0.212, g_loss=4.950
# epoch = 16/50, d_loss=0.177, g_loss=10.441
# epoch = 17/50, d_loss=0.191, g_loss=5.569
# epoch = 18/50, d_loss=0.319, g_loss=5.133
# epoch = 19/50, d_loss=0.210, g_loss=5.094
# epoch = 20/50, d_loss=0.250, g_loss=4.386
# epoch = 21/50, d_loss=0.355, g_loss=3.406
# epoch = 22/50, d_loss=0.196, g_loss=7.833
# epoch = 23/50, d_loss=0.209, g_loss=5.063
# epoch = 24/50, d_loss=0.201, g_loss=9.815
# epoch = 25/50, d_loss=0.204, g_loss=4.078
# epoch = 26/50, d_loss=0.181, g_loss=5.685
# epoch = 27/50, d_loss=0.191, g_loss=7.473
# epoch = 28/50, d_loss=0.179, g_loss=6.917
# epoch = 29/50, d_loss=0.185, g_loss=4.759
# epoch = 30/50, d_loss=0.194, g_loss=5.769
# epoch = 31/50, d_loss=0.212, g_loss=7.810
# epoch = 32/50, d_loss=0.196, g_loss=4.277
# epoch = 33/50, d_loss=0.227, g_loss=6.129
# epoch = 34/50, d_loss=0.267, g_loss=6.792
# epoch = 35/50, d_loss=0.183, g_loss=7.248
# epoch = 36/50, d_loss=0.273, g_loss=6.101
# epoch = 37/50, d_loss=0.506, g_loss=2.891
# epoch = 38/50, d_loss=0.216, g_loss=3.762
# epoch = 39/50, d_loss=0.193, g_loss=4.676
# epoch = 40/50, batch = 250/781, d_loss=0.183, g_loss=4.579

# %%
# plotting the metrics
plt.plot(d_loss)
plt.plot(g_loss)
plt.title('Model loss (DCGAN, CIFAR)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Discriminator', 'Adversarial'], loc='center right')
plt.show()

d_loss_for_plot = np.array(d_loss_for_plot)
g_loss_for_plot = np.array(g_loss_for_plot)
epochs_for_plot = np.arange(len(g_loss_for_plot))
plt.plot(epochs_for_plot, d_loss_for_plot[:, 1])
plt.plot(epochs_for_plot, g_loss_for_plot[:, 1])
plt.title('Model Accuracy (DCGAN, CIFAR)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Discriminator', 'Adversarial'], loc='center right')
plt.show()
